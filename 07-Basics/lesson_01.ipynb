# %% [markdown]
# # Image Augumentation

# %%
import os
import cv2 as cv
import matplotlib.pyplot as plt
import seaborn as sns
import pandas
import numpy

from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

# %%
! pip install azure-cognitiveservices-vision-computervision
# Out:
# Collecting azure-cognitiveservices-vision-computervision
#   Downloading azure_cognitiveservices_vision_computervision-0.9.0-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: azure-common~=1.1 in /Users/mahimairaja/opt/anaconda3/envs/aiml/lib/python3.10/site-packages (from azure-cognitiveservices-vision-computervision) (1.1.28)
# Collecting msrest>=0.5.0
#   Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /Users/mahimairaja/opt/anaconda3/envs/aiml/lib/python3.10/site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (1.3.1)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: requests~=2.16 in /Users/mahimairaja/opt/anaconda3/envs/aiml/lib/python3.10/site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (2.28.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mahimairaja/opt/anaconda3/envs/aiml/lib/python3.10/site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (2022.6.15)
# Requirement already satisfied: azure-core>=1.24.0 in /Users/mahimairaja/opt/anaconda3/envs/aiml/lib/python3.10/site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (1.24.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /Users/mahimairaja/opt/anaconda3/envs/aiml/lib/python3.10/site-packages (from azure-core>=1.24.0->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (4.2.0)
# Requirement already satisfied: six>=1.11.0 in /Users/mahimairaja/opt/anaconda3/envs/aiml/lib/python3.10/site-packages (from azure-core>=1.24.0->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/mahimairaja/opt/anaconda3/envs/aiml/lib/python3.10/site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mahimairaja/opt/anaconda3/envs/aiml/lib/python3.10/site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mahimairaja/opt/anaconda3/envs/aiml/lib/python3.10/site-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/mahimairaja/opt/anaconda3/envs/aiml/lib/python3.10/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (3.2.0)
# Installing collected packages: isodate, msrest, azure-cognitiveservices-vision-computervision
# Successfully installed azure-cognitiveservices-vision-computervision-0.9.0 isodate-0.6.1 msrest-0.7.1

# %%
! ls
# Out:
# 0001.jpeg       0002.jpeg       0003.jpeg       Untitled.ipynb  lesson_01.ipynb

# %%
img1 = cv.imread('data/0001.jpeg')
img2 = cv.imread('data/0002.jpeg')
img3 = cv.imread('data/0003.jpeg')

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
plt.imshow(img3)

# %%
dir(ComputerVisionClient)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'analyze_image',
#  'analyze_image_by_domain',
#  'analyze_image_by_domain_in_stream',
#  'analyze_image_in_stream',
#  'close',
#  'describe_image',
#  'describe_image_in_stream',
#  'detect_objects',
#  'detect_objects_in_stream',
#  'generate_thumbnail',
#  'generate_thumbnail_in_stream',
#  'get_area_of_interest',
#  'get_area_of_interest_in_stream',
#  'get_read_result',
#  'list_models',
#  'read',
#  'read_in_stream',
#  'recognize_printed_text',
#  'recognize_printed_text_in_stream',
#  'tag_image',
#  'tag_image_in_stream']

# %%
print(ComputerVisionClient.__dict__)
# Out:
# {'__module__': 'azure.cognitiveservices.vision.computervision._computer_vision_client', '__doc__': 'The Computer Vision API provides state-of-the-art algorithms to process images and return information. For example, it can be used to determine if an image contains mature content, or it can be used to find all the faces in an image.  It also has other features like estimating dominant and accent colors, categorizing the content of images, and describing an image with complete English sentences.  Additionally, it can also intelligently generate images thumbnails for displaying large images effectively.\n\n    :ivar config: Configuration for client.\n    :vartype config: ComputerVisionClientConfiguration\n\n    :param endpoint: Supported Cognitive Services endpoints.\n    :type endpoint: str\n    :param credentials: Subscription credentials which uniquely identify\n     client subscription.\n    :type credentials: None\n    ', '__init__': <function ComputerVisionClient.__init__ at 0x181b6b7f0>}
