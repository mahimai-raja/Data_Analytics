# %% [markdown]
# # Neural network with various hidden neuron and epochs

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
import seaborn as sb
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('datasets_heart_noheader.csv')
data.head()
# Out:
#    63  1  3  145  233  1.1  0  150  0.1  2.3  0.2  0.3  1.2  1.3
# 0  37  1  2  130  250    0  1  187    0  3.5    0    0    2    1
# 1  41  0  1  130  204    0  0  172    0  1.4    2    0    2    1
# 2  56  1  1  120  236    0  1  178    0  0.8    2    0    2    1
# 3  57  0  0  120  354    0  1  163    1  0.6    2    0    2    1
# 4  57  1  0  140  192    0  1  148    0  0.4    1    0    1    1

# %%
cor = data.corr()
print(cor)
sb.set(rc = {'figure.figsize':(15,8)})
sb.heatmap(cor, annot=True, )
plt.show()
# Out:
#            63         1         3       145       233       1.1         0  \
# 63   1.000000 -0.100823 -0.075475  0.277627  0.214832  0.115026 -0.113400
# 1   -0.100823  1.000000 -0.054194 -0.058593 -0.197507  0.040045 -0.056065
# 3   -0.075475 -0.054194  1.000000  0.042935 -0.075728  0.080077  0.051410
# 145  0.277627 -0.058593  0.042935  1.000000  0.123956  0.173292 -0.111854
# 233  0.214832 -0.197507 -0.075728  0.123956  1.000000  0.015475 -0.152165
# 1.1  0.115026  0.040045  0.080077  0.173292  0.015475  1.000000 -0.077077
# 0   -0.113400 -0.056065  0.051410 -0.111854 -0.152165 -0.077077  1.000000
# 150 -0.399170 -0.044089  0.297586 -0.046782 -0.009928 -0.008773  0.044249
# 0.1  0.099226  0.143460 -0.392581  0.069501  0.066492  0.031514 -0.073235
# 2.3  0.207301  0.093897 -0.157661  0.191024  0.054989 -0.002907 -0.055350
# 0.2 -0.163291 -0.025823  0.136629 -0.116838 -0.006021 -0.042630  0.086356
# 0.3  0.279234  0.120066 -0.177684  0.103384  0.069971  0.145150 -0.074610
# ...

# %%
Input = data.iloc[:, 0:13].values
Output = data.iloc[:, 13].values

# %%
x_train, x_test, y_train, y_test = train_test_split(Input, Output, random_state=2, test_size=0.2)

# %% [markdown]
# # Trial 1

# %%
modelA = Sequential()
# Out:
# 2022-06-15 22:34:06.986690: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
modelA.add(Dense(13, input_dim=13, activation='relu'))
modelA.add(Dense(28, activation='relu'))
modelA.add(Dense(1, activation='sigmoid'))

modelA.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
modelA.fit(x_train, y_train, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 25/25 [==============================] - 0s 867us/step - loss: 13.3030 - accuracy: 0.5602
# Epoch 2/150
# 25/25 [==============================] - 0s 724us/step - loss: 1.6204 - accuracy: 0.5145
# Epoch 3/150
# 25/25 [==============================] - 0s 637us/step - loss: 0.8699 - accuracy: 0.6224
# Epoch 4/150
# 25/25 [==============================] - 0s 652us/step - loss: 0.7777 - accuracy: 0.6058
# Epoch 5/150
# 25/25 [==============================] - 0s 626us/step - loss: 0.7396 - accuracy: 0.6183
# Epoch 6/150
# 25/25 [==============================] - 0s 619us/step - loss: 0.7399 - accuracy: 0.6307
# Epoch 7/150
# 25/25 [==============================] - 0s 619us/step - loss: 0.7531 - accuracy: 0.6141
# Epoch 8/150
# 25/25 [==============================] - 0s 630us/step - loss: 0.9026 - accuracy: 0.6224
# Epoch 9/150
# 25/25 [==============================] - 0s 613us/step - loss: 0.6939 - accuracy: 0.6680
# Epoch 10/150
# ...

# %%
# Model Evaluation

lossA , accuracyA = modelA.evaluate(x_test, y_test, verbose=1)

print(f'Test accuracy A = {accuracyA*100}')

lossAt , accuracyAt = modelA.evaluate(x_train, y_train, verbose=1)
print(f'Train accuracy A = {accuracyAt*100}')
# Out:
# 2/2 [==============================] - 0s 1ms/step - loss: 0.4861 - accuracy: 0.7705
# Test accuracy A = 77.04917788505554
# 8/8 [==============================] - 0s 844us/step - loss: 0.3475 - accuracy: 0.8589
# Train accuracy A = 85.89211702346802

# %% [markdown]
# # Trial 2

# %%
modelB = Sequential()

# %%
modelB.add(Dense(13, input_dim=13, activation='relu'))
modelB.add(Dense(35, activation='relu'))
modelB.add(Dense(1, activation='sigmoid'))

modelB.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
modelB.fit(x_train, y_train, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 25/25 [==============================] - 0s 706us/step - loss: 3.4273 - accuracy: 0.3983
# Epoch 2/150
# 25/25 [==============================] - 0s 854us/step - loss: 1.6657 - accuracy: 0.4274
# Epoch 3/150
# 25/25 [==============================] - 0s 691us/step - loss: 1.2215 - accuracy: 0.4523
# Epoch 4/150
# 25/25 [==============================] - 0s 686us/step - loss: 0.9584 - accuracy: 0.5353
# Epoch 5/150
# 25/25 [==============================] - 0s 617us/step - loss: 0.9562 - accuracy: 0.5311
# Epoch 6/150
# 25/25 [==============================] - 0s 603us/step - loss: 0.7791 - accuracy: 0.5975
# Epoch 7/150
# 25/25 [==============================] - 0s 618us/step - loss: 0.7316 - accuracy: 0.6100
# Epoch 8/150
# 25/25 [==============================] - 0s 596us/step - loss: 0.6775 - accuracy: 0.6556
# Epoch 9/150
# 25/25 [==============================] - 0s 586us/step - loss: 0.8080 - accuracy: 0.6058
# Epoch 10/150
# ...

# %%
lossB, accuracyB = modelB.evaluate(x_test, y_test, verbose=1)
lossBt , accuracyBt = modelB.evaluate(x_train, y_train, verbose=1)

print(f'Test accuracy B = {accuracyB*100}')
print(f'Train accuracy B = {accuracyBt*100}')
# Out:
# ...
# 8/8 [==============================] - 0s 823us/step - loss: 0.4223 - accuracy: 0.8050
# Test accuracy B = 77.04917788505554
# Train accuracy B = 80.49792647361755

# %% [markdown]
# # Trial 3

# %%
modelC = Sequential()

# %%
modelC.add(Dense(13, input_dim=13, activation='relu'))
modelC.add(Dense(65, activation='relu'))
modelC.add(Dense(1, activation='sigmoid'))

modelC.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
modelC.fit(x_train, y_train, epochs=1500, batch_size=10)
# Out:
# Epoch 1/1500
# 25/25 [==============================] - 0s 745us/step - loss: 4.9698 - accuracy: 0.5353
# Epoch 2/1500
# 25/25 [==============================] - 0s 776us/step - loss: 0.9069 - accuracy: 0.6141
# Epoch 3/1500
# 25/25 [==============================] - 0s 654us/step - loss: 0.6564 - accuracy: 0.6929
# Epoch 4/1500
# 25/25 [==============================] - 0s 648us/step - loss: 0.6457 - accuracy: 0.6307
# Epoch 5/1500
# 25/25 [==============================] - 0s 630us/step - loss: 0.5807 - accuracy: 0.6722
# Epoch 6/1500
# 25/25 [==============================] - 0s 630us/step - loss: 0.6854 - accuracy: 0.6598
# Epoch 7/1500
# 25/25 [==============================] - 0s 634us/step - loss: 0.5917 - accuracy: 0.7220
# Epoch 8/1500
# 25/25 [==============================] - 0s 618us/step - loss: 0.5736 - accuracy: 0.6805
# Epoch 9/1500
# 25/25 [==============================] - 0s 601us/step - loss: 0.7483 - accuracy: 0.6017
# Epoch 10/1500
# ...

# %%
lossC , accuracyC = modelC.evaluate(x_test, y_test, verbose=1)
lossCt , accuracyCt = modelC.evaluate(x_train, y_train, verbose=1)

print(f'Test accuracy c = {accuracyC*100}')
print(f'Train accuracy C = {accuracyCt*100}')
# Out:
# ...
# 8/8 [==============================] - 0s 595us/step - loss: 0.0789 - accuracy: 0.9710
# Test accuracy c = 75.40983557701111
# Train accuracy C = 97.09543585777283

# %% [markdown]
# # Trial 4

# %%
modelD = Sequential()

# %%
modelD.add(Dense(13, input_dim=13, activation='relu'))
modelD.add(Dense(4, activation='relu'))
modelD.add(Dense(1, activation='sigmoid'))

modelD.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
modelD.fit(x_train, y_train, epochs=2, batch_size=10)
# Out:
# Epoch 1/2
# 25/25 [==============================] - 0s 748us/step - loss: 0.6901 - accuracy: 0.5519
# Epoch 2/2
# 25/25 [==============================] - 0s 739us/step - loss: 0.6896 - accuracy: 0.5602

# %%
lossD, accuaracyD = modelD.evaluate(x_test, y_test, verbose=1)
lossDt , accuracyDt = modelD.evaluate(x_train, y_train, verbose=1)

print(f'Test accuracy D = {accuaracyD*100}')
print(f'Train accuracy D = {accuracyDt*100}')
# Out:
# ...
# 8/8 [==============================] - 0s 595us/step - loss: 0.6894 - accuracy: 0.5602
# Test accuracy D = 47.54098355770111
# Train accuracy D = 56.016600131988525

# %% [markdown]
# # Trial 5

# %%
modelE = Sequential()

# %%
modelE.add(Dense(13, input_dim = 13, activation='relu'))
modelE.add(Dense(100, activation='relu'))
modelE.add(Dense(1, activation='sigmoid'))

modelE.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
modelE.fit(x_train, y_train, epochs=2500, batch_size=10)
# Out:
# Epoch 1/2500
# 25/25 [==============================] - 0s 686us/step - loss: 2.1676 - accuracy: 0.4564
# Epoch 2/2500
# 25/25 [==============================] - 0s 776us/step - loss: 0.9458 - accuracy: 0.5353
# Epoch 3/2500
# 25/25 [==============================] - 0s 638us/step - loss: 0.6795 - accuracy: 0.5643
# Epoch 4/2500
# 25/25 [==============================] - 0s 693us/step - loss: 0.6587 - accuracy: 0.6058
# Epoch 5/2500
# 25/25 [==============================] - 0s 617us/step - loss: 0.6349 - accuracy: 0.6349
# Epoch 6/2500
# 25/25 [==============================] - 0s 582us/step - loss: 0.6487 - accuracy: 0.6307
# Epoch 7/2500
# 25/25 [==============================] - 0s 587us/step - loss: 0.6298 - accuracy: 0.6639
# Epoch 8/2500
# 25/25 [==============================] - 0s 605us/step - loss: 0.6312 - accuracy: 0.6763
# Epoch 9/2500
# 25/25 [==============================] - 0s 609us/step - loss: 0.5919 - accuracy: 0.6929
# Epoch 10/2500
# ...

# %%
lossE, accuracyE = modelE.evaluate(x_test, y_test, verbose=1)
lossEt , accuracyEt = modelE.evaluate(x_train, y_train, verbose=1)

print(f'Test accuracy E = {accuracyE*100}')
print(f'Train accuracy E = {accuracyEt*100}')
# Out:
# ...
# 8/8 [==============================] - 0s 566us/step - loss: 0.0015 - accuracy: 1.0000
# Test accuracy E = 75.40983557701111
# Train accuracy E = 100.0

# %% [markdown]
# # Trial 6

# %%
modelF = Sequential()

# %%
modelF.add(Dense(13, input_dim = 13, activation='relu'))
modelF.add(Dense(8, activation='relu'))
modelF.add(Dense(1, activation='sigmoid'))

modelF.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
modelF.fit(x_train, y_train, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 25/25 [==============================] - 0s 711us/step - loss: 50.3253 - accuracy: 0.4398
# Epoch 2/150
# 25/25 [==============================] - 0s 783us/step - loss: 23.4300 - accuracy: 0.4398
# Epoch 3/150
# 25/25 [==============================] - 0s 680us/step - loss: 9.7044 - accuracy: 0.4398
# Epoch 4/150
# 25/25 [==============================] - 0s 632us/step - loss: 1.8575 - accuracy: 0.5519
# Epoch 5/150
# 25/25 [==============================] - 0s 635us/step - loss: 1.3948 - accuracy: 0.5975
# Epoch 6/150
# 25/25 [==============================] - 0s 634us/step - loss: 1.0377 - accuracy: 0.6100
# Epoch 7/150
# 25/25 [==============================] - 0s 623us/step - loss: 0.8804 - accuracy: 0.6183
# Epoch 8/150
# 25/25 [==============================] - 0s 641us/step - loss: 0.8689 - accuracy: 0.6473
# Epoch 9/150
# 25/25 [==============================] - 0s 643us/step - loss: 0.8024 - accuracy: 0.6473
# Epoch 10/150
# ...

# %%
lossF, accuracyF = modelF.evaluate(x_test, y_test, verbose=1)
lossFt , accuracyFt = modelF.evaluate(x_train, y_train, verbose=1)

print(f'Test accuracy F = {accuracyF*100}')
print(f'Train accuracy F = {accuracyFt*100}')
# Out:
# ...
# 8/8 [==============================] - 0s 733us/step - loss: 0.4481 - accuracy: 0.7801
# Test accuracy F = 75.40983557701111
# Train accuracy F = 78.00830006599426

# %% [markdown]
# # Trial 7

# %%
modelG = Sequential()

# %%
modelG.add(Dense(13, input_dim = 13, activation='relu'))
modelG.add(Dense(120, activation='relu'))
modelG.add(Dense(1, activation='sigmoid'))

modelG.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
modelG.fit(x_train, y_train, epochs=2500, batch_size=10)
# Out:
# Epoch 1/2500
# 25/25 [==============================] - 0s 709us/step - loss: 1.1797 - accuracy: 0.5726
# Epoch 2/2500
# 25/25 [==============================] - 0s 752us/step - loss: 1.0254 - accuracy: 0.6183
# Epoch 3/2500
# 25/25 [==============================] - 0s 671us/step - loss: 0.6572 - accuracy: 0.7054
# Epoch 4/2500
# 25/25 [==============================] - 0s 637us/step - loss: 0.6313 - accuracy: 0.6888
# Epoch 5/2500
# 25/25 [==============================] - 0s 620us/step - loss: 0.6696 - accuracy: 0.6846
# Epoch 6/2500
# 25/25 [==============================] - 0s 613us/step - loss: 0.6592 - accuracy: 0.6805
# Epoch 7/2500
# 25/25 [==============================] - 0s 623us/step - loss: 0.6680 - accuracy: 0.6639
# Epoch 8/2500
# 25/25 [==============================] - 0s 633us/step - loss: 0.6531 - accuracy: 0.6763
# Epoch 9/2500
# 25/25 [==============================] - 0s 628us/step - loss: 0.6469 - accuracy: 0.6846
# Epoch 10/2500
# ...

# %%
lossG, accuracyG = modelG.evaluate(x_test, y_test, verbose=1)
lossG, accuracyGt = modelG.evaluate(x_train, y_train, verbose=1)

print(f'Test accuracy G = {accuracyG*100}')
print(f'Train accuracy G = {accuracyGt*100}')
# Out:
# ...
# 8/8 [==============================] - 0s 596us/step - loss: 0.1127 - accuracy: 0.9585
# Test accuracy G = 75.40983557701111
# Train accuracy G = 95.85062265396118

# %% [markdown]
# # Trial 8

# %%
modelH = Sequential()

# %%
modelH.add(Dense(13, input_dim = 13, activation='relu'))
modelH.add(Dense(1, activation='relu'))
modelH.add(Dense(1, activation='sigmoid'))

modelH.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
modelH.fit(x_train, y_train, epochs=500, batch_size=10)
# Out:
# Epoch 1/500
# 25/25 [==============================] - 0s 744us/step - loss: 53.9923 - accuracy: 0.4398
# Epoch 2/500
# 25/25 [==============================] - 0s 795us/step - loss: 12.0250 - accuracy: 0.4647
# Epoch 3/500
# 25/25 [==============================] - 0s 668us/step - loss: 1.5625 - accuracy: 0.5021
# Epoch 4/500
# 25/25 [==============================] - 0s 650us/step - loss: 0.9173 - accuracy: 0.5436
# Epoch 5/500
# 25/25 [==============================] - 0s 607us/step - loss: 0.8316 - accuracy: 0.5477
# Epoch 6/500
# 25/25 [==============================] - 0s 697us/step - loss: 0.7935 - accuracy: 0.5477
# Epoch 7/500
# 25/25 [==============================] - 0s 625us/step - loss: 0.7545 - accuracy: 0.5519
# Epoch 8/500
# 25/25 [==============================] - 0s 618us/step - loss: 0.7314 - accuracy: 0.5519
# Epoch 9/500
# 25/25 [==============================] - 0s 610us/step - loss: 0.7192 - accuracy: 0.5560
# Epoch 10/500
# ...

# %%
lossH, accuracyH = modelG.evaluate(x_test, y_test, verbose=1)
lossHt , accuracyHt = modelH.evaluate(x_train, y_train, verbose=1)

print(f'Test accuracy H = {accuracyH*100}')
print(f'Train accuracy H = {accuracyHt*100}')
# Out:
# ...
# 8/8 [==============================] - 0s 584us/step - loss: 0.6859 - accuracy: 0.5602
# Test accuracy H = 75.40983557701111
# Train accuracy H = 56.016600131988525

# %% [markdown]
# # Trial 9

# %%
modelI = Sequential()

# %%
modelI.add(Dense(13, input_dim = 13, activation='relu'))
modelI.add(Dense(8, activation='relu'))
modelI.add(Dense(1, activation='sigmoid'))

modelI.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
modelI.fit(x_train, y_train, epochs=15, batch_size=10)
# Out:
# Epoch 1/15
# 25/25 [==============================] - 0s 772us/step - loss: 12.0922 - accuracy: 0.4481
# Epoch 2/15
# 25/25 [==============================] - 0s 743us/step - loss: 2.3064 - accuracy: 0.5560
# Epoch 3/15
# 25/25 [==============================] - 0s 676us/step - loss: 1.5278 - accuracy: 0.5643
# Epoch 4/15
# 25/25 [==============================] - 0s 680us/step - loss: 1.1206 - accuracy: 0.6183
# Epoch 5/15
# 25/25 [==============================] - 0s 637us/step - loss: 0.8677 - accuracy: 0.6390
# Epoch 6/15
# 25/25 [==============================] - 0s 630us/step - loss: 0.8181 - accuracy: 0.6349
# Epoch 7/15
# 25/25 [==============================] - 0s 601us/step - loss: 0.7572 - accuracy: 0.6598
# Epoch 8/15
# 25/25 [==============================] - 0s 606us/step - loss: 0.7043 - accuracy: 0.6432
# Epoch 9/15
# 25/25 [==============================] - 0s 600us/step - loss: 0.6391 - accuracy: 0.6763
# Epoch 10/15
# ...

# %%
lossI, accuracyI = modelI.evaluate(x_test, y_test, verbose=1)
lossIt , accuracyIt = modelI.evaluate(x_train, y_train, verbose=1)

print(f'Test accuracy I = {accuracyI*100}')
print(f'Train accuracy I = {accuracyIt*100}')
# Out:
# ...
# 8/8 [==============================] - 0s 580us/step - loss: 0.5229 - accuracy: 0.7427
# Test accuracy I = 67.21311211585999
# Train accuracy I = 74.27386045455933

# %% [markdown]
# # Accuracy

# %%
print(f'Test accuracy A = {accuracyA*100}')
print(f'Train accuracy A = {accuracyAt*100}\n')

print(f'Test accuracy B = {accuracyB*100}')
print(f'Train accuracy B = {accuracyBt*100}\n')

print(f'Test accuracy c = {accuracyC*100}')
print(f'Train accuracy C = {accuracyCt*100}\n')

print(f'Test accuracy D = {accuaracyD*100}')
print(f'Train accuracy D = {accuracyDt*100}\n')

print(f'Test accuracy E = {accuracyE*100}')
print(f'Train accuracy E = {accuracyEt*100}\n')

print(f'Test accuracy F = {accuracyF*100}')
print(f'Train accuracy F = {accuracyFt*100}\n')

print(f'Test accuracy G = {accuracyG*100}')
print(f'Train accuracy G = {accuracyGt*100}\n')

print(f'Test accuracy H = {accuracyH*100}')
print(f'Train accuracy H = {accuracyHt*100}\n')

print(f'Test accuracy I = {accuracyI*100}')
print(f'Train accuracy I = {accuracyIt*100}\n')
# Out:
# Test accuracy A = 77.04917788505554
# Train accuracy A = 85.89211702346802
#
# Test accuracy B = 77.04917788505554
# Train accuracy B = 80.49792647361755
#
# Test accuracy c = 75.40983557701111
# Train accuracy C = 97.09543585777283
#
# Test accuracy D = 47.54098355770111
# Train accuracy D = 56.016600131988525
#
# Test accuracy E = 75.40983557701111
# Train accuracy E = 100.0
#
# Test accuracy F = 75.40983557701111
# Train accuracy F = 78.00830006599426
#
# Test accuracy G = 75.40983557701111
# Train accuracy G = 95.85062265396118
#
# Test accuracy H = 75.40983557701111
# Train accuracy H = 56.016600131988525
#
# Test accuracy I = 67.21311211585999
# Train accuracy I = 74.27386045455933

# %% [markdown]
# ![Screenshot%202022-06-15%20at%203.07.22%20PM.png](attachment:Screenshot%202022-06-15%20at%203.07.22%20PM.png)
