# %% [markdown]
# # Diabeties_Prediction

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
data = pd.read_csv('datasets_228_482_diabetes_nh.csv')
data.head()
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %%
Input = data.iloc[:,0:8].values
Output  = data.iloc[:,8].values

# %%
x_train, x_test, y_train, y_test = train_test_split(Input, Output, test_size=0.2, random_state=3)

# %%
x_train
# Out:
# array([[  6.   , 154.   ,  78.   , ...,  46.1  ,   0.571,  27.   ],
#        [  4.   , 132.   ,  86.   , ...,  28.   ,   0.419,  63.   ],
#        [  3.   ,  83.   ,  58.   , ...,  34.3  ,   0.336,  25.   ],
#        ...,
#        [  3.   , 103.   ,  72.   , ...,  27.6  ,   0.73 ,  27.   ],
#        [  9.   , 106.   ,  52.   , ...,  31.2  ,   0.38 ,  42.   ],
#        [  1.   , 112.   ,  80.   , ...,  34.8  ,   0.217,  24.   ]])

# %%
model = Sequential()
model.add(Dense(16, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
print(type(model))
# Out:
# <class 'keras.engine.sequential.Sequential'>

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=1000, batch_size=20, verbose=1)

# verbose - decide how to shoe the training process
# Out:
# Epoch 1/1000
# 31/31 [==============================] - 0s 590us/step - loss: 0.3408 - accuracy: 0.8238
# Epoch 2/1000
# 31/31 [==============================] - 0s 643us/step - loss: 0.3257 - accuracy: 0.8499
# Epoch 3/1000
# 31/31 [==============================] - 0s 573us/step - loss: 0.3130 - accuracy: 0.8418
# Epoch 4/1000
# 31/31 [==============================] - 0s 541us/step - loss: 0.3142 - accuracy: 0.8434
# Epoch 5/1000
# 31/31 [==============================] - 0s 538us/step - loss: 0.3182 - accuracy: 0.8450
# Epoch 6/1000
# 31/31 [==============================] - 0s 538us/step - loss: 0.3407 - accuracy: 0.8450
# Epoch 7/1000
# 31/31 [==============================] - 0s 542us/step - loss: 0.3292 - accuracy: 0.8271
# Epoch 8/1000
# 31/31 [==============================] - 0s 535us/step - loss: 0.3221 - accuracy: 0.8450
# Epoch 9/1000
# 31/31 [==============================] - 0s 545us/step - loss: 0.3223 - accuracy: 0.8532
# Epoch 10/1000
# ...

# %%
# The evaluate function returns : loss_figure and accuracy

loss_figure , accuracy = model.evaluate(x_test, y_test, verbose=1)
print(f'{accuracy*100}')
print(f'{loss_figure*100}')
# Out:
# 5/5 [==============================] - 0s 780us/step - loss: 1.6264 - accuracy: 0.7078
# 70.77922224998474
# 162.6370072364807
